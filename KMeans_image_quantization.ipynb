# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
from sklearn.cluster import KMeans

# %%
image = mpimg.imread('palm_trees.jpg')

# %%
plt.figure(figsize=(6,10),dpi=150)
plt.imshow(image)

# %%
image.shape
# Out:
# (1401, 934, 3)

# %%
(h,w,c) = image.shape

# %%
image_2d = image.reshape(h*w,c)

# %%
image_2d.shape
# Out:
# (1308534, 3)

# %%
# Model Traiinig

# %%
model = KMeans(n_clusters=6)
labels = model.fit_predict(image_2d)

# %%
model.cluster_centers_
# Out:
# array([[219.20506736, 135.3184584 ,  46.64169835],
#        [  2.76743149,   2.58759727,   3.71399576],
#        [137.00581205, 143.83017978, 143.8903002 ],
#        [ 71.12029394, 109.28069542, 137.7039712 ],
#        [191.86784817, 154.51571479, 109.15096885],
#        [ 67.56132559,  61.71400226,  62.10127198]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes[labels]
# Out:
# array([[ 71, 109, 138],
#        [ 71, 109, 138],
#        [ 71, 109, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]])

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.figure(figsize=(6,10),dpi=150)
plt.imshow(quantized_image)
